# %% [markdown]
# # 🏥 Hospital Data Analytics Project
# ## Department Dimension Data Cleaning This notebook cleans and validates the Department Dimension dataset.
# Input: dim_department.csv
# Output: dim_department_clean.csv

# %%
# ==============================================================================
# IMPORT REQUIRED LIBRARIES
# ==============================================================================

import os
import numpy as np
import pandas as pd

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# ==============================================================================
# FILE CONFIGURATION
# ==============================================================================

INPUT_DIR = os.path.join(
    "..",
    "02_Data_Generation",
    "03_Datasets",
    "CSV_Files"
)

OUTPUT_DIR = "CSV_Files"

os.makedirs(
    OUTPUT_DIR,
    exist_ok=True
)

INPUT_FILE = os.path.join(
    INPUT_DIR,
    "dim_department.csv"
)

OUTPUT_FILE = os.path.join(
    OUTPUT_DIR,
    "dim_department_clean.csv"
)

print("=" * 80)
print("FILE CONFIGURATION")
print("=" * 80)

print(f"Input File  : {INPUT_FILE}")
print(f"Output File : {OUTPUT_FILE}")
print(f"File Exists : {os.path.exists(INPUT_FILE)}")
# Out:
# ...
# FILE CONFIGURATION
# ...
# Input File  : ..\02_Data_Generation\03_Datasets\CSV_Files\dim_department.csv
# Output File : CSV_Files\dim_department_clean.csv
# File Exists : False
