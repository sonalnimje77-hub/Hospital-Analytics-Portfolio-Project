# %%
"""
==============================================================================
Project : Hospital Analytics Portfolio Project
File    : config.py
Purpose : Global Project Configuration
Author  : Your Name
Version : 1.0
==============================================================================

This file stores all global configuration settings used throughout the project.

Contents
--------
1. Project Information
2. Folder Locations
3. Dataset File Paths
4. Export Settings
5. Random Seed
6. Dataset Sizes
7. Date Settings
8. Logging Settings
9. Automatically Create Required Folders
==============================================================================
"""

# ==============================================================================
# IMPORT LIBRARIES
# ==============================================================================

from pathlib import Path

# ==============================================================================
# PROJECT INFORMATION
# ==============================================================================

PROJECT_NAME = "Hospital Analytics Portfolio Project"

PROJECT_VERSION = "1.0"

AUTHOR = "Your Name"

# ==============================================================================
# PROJECT ROOT DIRECTORY
# ==============================================================================

# Jupyter Notebook Compatible
PROJECT_ROOT = Path.cwd()

print(f"Project Root : {PROJECT_ROOT}")

# ==============================================================================
# PROJECT FOLDERS
# ==============================================================================

DOCUMENT_FOLDER = PROJECT_ROOT / "01_Project_Documentation"

SQL_FOLDER = PROJECT_ROOT / "02_SQL"

DATASET_FOLDER = PROJECT_ROOT / "03_Datasets"

CSV_FOLDER = DATASET_FOLDER / "CSV_Files"

EXCEL_FOLDER = DATASET_FOLDER / "Excel_Files"

PYTHON_FOLDER = PROJECT_ROOT / "04_Python"

CONFIG_FOLDER = PYTHON_FOLDER / "01_Config"

DATA_GENERATION_FOLDER = PYTHON_FOLDER / "02_Data_Generation"

DATA_CLEANING_FOLDER = PYTHON_FOLDER / "03_Data_Cleaning"

EDA_FOLDER = PYTHON_FOLDER / "04_EDA"

EXPORT_FOLDER = PYTHON_FOLDER / "05_Export"

LOG_FOLDER = PROJECT_ROOT / "05_Logs"

POWERBI_FOLDER = PROJECT_ROOT / "06_PowerBI"

EXCEL_DASHBOARD_FOLDER = PROJECT_ROOT / "07_Excel"

# ==============================================================================
# DIMENSION DATASET FILES
# ==============================================================================

PATIENT_FILE = CSV_FOLDER / "dim_patient.csv"

DOCTOR_FILE = CSV_FOLDER / "dim_doctor.csv"

DEPARTMENT_FILE = CSV_FOLDER / "dim_department.csv"

DATE_FILE = CSV_FOLDER / "dim_date.csv"

INSURANCE_FILE = CSV_FOLDER / "dim_insurance.csv"

WARD_FILE = CSV_FOLDER / "dim_ward.csv"

BED_FILE = CSV_FOLDER / "dim_bed.csv"

MEDICINE_FILE = CSV_FOLDER / "dim_medicine.csv"

LAB_TEST_FILE = CSV_FOLDER / "dim_lab_test.csv"

DIAGNOSIS_FILE = CSV_FOLDER / "dim_diagnosis.csv"

PAYMENT_MODE_FILE = CSV_FOLDER / "dim_payment_mode.csv"

# ==============================================================================
# FACT DATASET FILES
# ==============================================================================

APPOINTMENT_FILE = CSV_FOLDER / "fact_appointments.csv"

OPD_FILE = CSV_FOLDER / "fact_opd_visits.csv"

IPD_FILE = CSV_FOLDER / "fact_ipd_admissions.csv"

BILLING_FILE = CSV_FOLDER / "fact_billing.csv"

INSURANCE_CLAIM_FILE = CSV_FOLDER / "fact_insurance_claims.csv"

PHARMACY_FILE = CSV_FOLDER / "fact_pharmacy.csv"

LAB_ORDER_FILE = CSV_FOLDER / "fact_lab_orders.csv"

WAITING_FILE = CSV_FOLDER / "fact_waiting_time.csv"

FEEDBACK_FILE = CSV_FOLDER / "fact_patient_feedback.csv"

COMPLAINT_FILE = CSV_FOLDER / "fact_complaints.csv"

EMERGENCY_FILE = CSV_FOLDER / "fact_emergency.csv"

SURGERY_FILE = CSV_FOLDER / "fact_surgeries.csv"

RADIOLOGY_FILE = CSV_FOLDER / "fact_radiology.csv"

DISCHARGE_FILE = CSV_FOLDER / "fact_discharge.csv"

BED_OCCUPANCY_FILE = CSV_FOLDER / "fact_bed_occupancy.csv"

# ==============================================================================
# EXPORT SETTINGS
# ==============================================================================

CSV_ENCODING = "utf-8"

CSV_SEPARATOR = ","

EXPORT_INDEX = False

EXCEL_ENGINE = "openpyxl"

# ==============================================================================
# RANDOM SEED
# ==============================================================================

RANDOM_SEED = 100

# ==============================================================================
# DATASET SIZE
# ==============================================================================

TOTAL_PATIENTS = 15000

TOTAL_DOCTORS = 120

TOTAL_DEPARTMENTS = 18

TOTAL_MEDICINES = 600

TOTAL_LAB_TESTS = 150

TOTAL_APPOINTMENTS = 150000

TOTAL_OPD_VISITS = 90000

TOTAL_IPD_ADMISSIONS = 25000

TOTAL_BILLS = 150000

TOTAL_PHARMACY = 120000

TOTAL_LAB_ORDERS = 80000

TOTAL_FEEDBACK = 25000

TOTAL_COMPLAINTS = 8000

TOTAL_EMERGENCY = 18000

TOTAL_SURGERIES = 10000

TOTAL_RADIOLOGY = 30000

TOTAL_DISCHARGE = 25000

TOTAL_BED_OCCUPANCY = 40000

# ==============================================================================
# DATE SETTINGS
# ==============================================================================

START_DATE = "2023-01-01"

END_DATE = "2025-12-31"

DATE_FORMAT = "%Y-%m-%d"

DATETIME_FORMAT = "%Y-%m-%d %H:%M:%S"

# ==============================================================================
# LOGGING
# ==============================================================================

LOG_FILE = LOG_FOLDER / "hospital_project.log"

LOG_LEVEL = "INFO"

# ==============================================================================
# REQUIRED PROJECT FOLDERS
# ==============================================================================

REQUIRED_FOLDERS = [

    DOCUMENT_FOLDER,

    SQL_FOLDER,

    DATASET_FOLDER,

    CSV_FOLDER,

    EXCEL_FOLDER,

    PYTHON_FOLDER,

    CONFIG_FOLDER,

    DATA_GENERATION_FOLDER,

    DATA_CLEANING_FOLDER,

    EDA_FOLDER,

    EXPORT_FOLDER,

    LOG_FOLDER,

    POWERBI_FOLDER,

    EXCEL_DASHBOARD_FOLDER

]

# ==============================================================================
# CREATE PROJECT FOLDERS
# ==============================================================================

for folder in REQUIRED_FOLDERS:

    folder.mkdir(parents=True, exist_ok=True)

# ==============================================================================
# DISPLAY CONFIGURATION
# ==============================================================================

print("\n" + "=" * 70)
print("PROJECT CONFIGURATION LOADED SUCCESSFULLY")
print("=" * 70)

print(f"Project Name        : {PROJECT_NAME}")
print(f"Version             : {PROJECT_VERSION}")
print(f"Author              : {AUTHOR}")

print("\nFolder Locations")
print("-" * 70)
print(f"Project Root        : {PROJECT_ROOT}")
print(f"Documentation       : {DOCUMENT_FOLDER}")
print(f"SQL Folder          : {SQL_FOLDER}")
print(f"Dataset Folder      : {DATASET_FOLDER}")
print(f"CSV Folder          : {CSV_FOLDER}")
print(f"Excel Folder        : {EXCEL_FOLDER}")
print(f"Python Folder       : {PYTHON_FOLDER}")
print(f"Power BI Folder     : {POWERBI_FOLDER}")
print(f"Excel Dashboard     : {EXCEL_DASHBOARD_FOLDER}")
print(f"Logs Folder         : {LOG_FOLDER}")

print("\nDataset Information")
print("-" * 70)
print(f"Patients            : {TOTAL_PATIENTS:,}")
print(f"Doctors             : {TOTAL_DOCTORS:,}")
print(f"Departments         : {TOTAL_DEPARTMENTS}")
print(f"Medicines           : {TOTAL_MEDICINES}")
print(f"Lab Tests           : {TOTAL_LAB_TESTS}")
print(f"Appointments        : {TOTAL_APPOINTMENTS:,}")
print(f"OPD Visits          : {TOTAL_OPD_VISITS:,}")
print(f"IPD Admissions      : {TOTAL_IPD_ADMISSIONS:,}")
print(f"Billing Records     : {TOTAL_BILLS:,}")
print(f"Pharmacy Records    : {TOTAL_PHARMACY:,}")
print(f"Lab Orders          : {TOTAL_LAB_ORDERS:,}")

print("\nDate Range")
print("-" * 70)
print(f"Start Date          : {START_DATE}")
print(f"End Date            : {END_DATE}")

print("=" * 70)
print("All required folders have been created successfully.")
print("=" * 70)

# ==============================================================================
# END OF FILE
# ==============================================================================
# Out:
# Project Root : C:\Users\lenovo\Hospital Data Analytics
#
# ======================================================================
# PROJECT CONFIGURATION LOADED SUCCESSFULLY
# ======================================================================
# Project Name        : Hospital Analytics Portfolio Project
# Version             : 1.0
# Author              : Your Name
#
# Folder Locations
# ----------------------------------------------------------------------
# Project Root        : C:\Users\lenovo\Hospital Data Analytics
# Documentation       : C:\Users\lenovo\Hospital Data Analytics\01_Project_Documentation
# SQL Folder          : C:\Users\lenovo\Hospital Data Analytics\02_SQL
# Dataset Folder      : C:\Users\lenovo\Hospital Data Analytics\03_Datasets
# CSV Folder          : C:\Users\lenovo\Hospital Data Analytics\03_Datasets\CSV_Files
# Excel Folder        : C:\Users\lenovo\Hospital Data Analytics\03_Datasets\Excel_Files
# Python Folder       : C:\Users\lenovo\Hospital Data Analytics\04_Python
# Power BI Folder     : C:\Users\lenovo\Hospital Data Analytics\06_PowerBI
# Excel Dashboard     : C:\Users\lenovo\Hospital Data Analytics\07_Excel
# Logs Folder         : C:\Users\lenovo\Hospital Data Analytics\05_Logs
#
# Dataset Information
# ----------------------------------------------------------------------
# Patients            : 15,000
# Doctors             : 120
# Departments         : 18
# Medicines           : 600
# Lab Tests           : 150
# Appointments        : 150,000
# OPD Visits          : 90,000
# IPD Admissions      : 25,000
# Billing Records     : 150,000
# Pharmacy Records    : 120,000
# Lab Orders          : 80,000
#
# Date Range
# ----------------------------------------------------------------------
# Start Date          : 2023-01-01
# End Date            : 2025-12-31
# ======================================================================
# All required folders have been created successfully.
# ======================================================================
